# %%
from modsim import *
# %matplotlib notebook

# %% [markdown]
# http://www.pveducation.org/pvcdrom/2-properties-sunlight/solar-radiation-space

# %%
kg= UNITS.kg
m= UNITS.m
N= UNITS.N
W= UNITS.W
K= UNITS.K
j= UNITS.joules
s= UNITS.seconds
degrees= UNITS.degrees

# %%
mass_sun= 1.989e30 
G= 6.673e-11
mass_toast= .05
S_B_const= 5.67e-8
temp_S= 5772 
area_t= .01 
r_s= 695770 *1000 
Pow_s= 3.9e26 
Q_b= .008/273 

power_sun = S_B_const * temp_S *4 *pi *r_s**2 
 

num_G = G* mass_sun *mass_toast   

num_G


 

#I think these are all the equations and constants we need. I found a specific heat for bread that was in kg and C, 
#which I think I converted into Kelvin but it's a bit sketchy. I'm also not sure about the area of the sunward facing 
#toast side, but we can look back at that.
# Out:
# 6.6362985e+18

# %%
condition= Condition(x0= 1e100, y0= 0, velocity= 50000, angle = 40, duration= 1e100, T0= 0 )

# %%
#I'm not sure I'm doing this right, I'm mostly copying this from chapter 10 with the intro to vectors and the baseball. 

def make_system(condition):
    unpack(condition)
    
    theta = np.deg2rad(angle)
    
    vx, vy = pol2cart(theta, velocity)
    
    init= State(x=x0, y=y0, vx= vx, vy= vy)
    area_toast = area_t 
    
    ts= linspace(0, duration, 1000)
    
    return System(init= init, mass= mass_toast, area_t= area_t, T= T0, Q_b= Q_b, ts= ts)

system= make_system(condition)

# %%
def slope_func(state, t, system):
    x, y, vx, vy = state
    
    unpack(system)
    P= Vector(x, y) 
    V= Vector(vx, vy) 
    Tangent_dir= Vector(x, -y) 
    w= V.proj(Tangent_dir) * Tangent_dir.hat() 

    F_grav= num_G / P.mag **2 * P.hat() 
    F_cent= w**2  *mass_toast / P.mag  * Tangent_dir.hat()
    
   
    
    a_grav= (F_grav/mass_toast) * P.hat() 
    a_cent= (F_cent/mass_toast) *Tangent_dir.hat() 
    
    
    ax= a_grav[0] + a_cent[0]
    ay= a_grav[1] + a_cent[1]
    
    a= Vector(ax, ay)

    
    
    rad_on_toast= t * Pow_s * r_s**2/ P.mag**2 
    temp_toast= rad_on_toast/ Q_b / mass_toast 
    
    
    return vx, vy, a.x, a.y
    
    
    
slope_func(system.init,1,system)
# Out:
# (38302.222155948897,
#  32139.380484326961,
#  <Quantity(1.4670602220836628e+109, 'dimensionless')>,
#  <Quantity(0.0, 'dimensionless')>)

# %%
run_odeint(system, slope_func)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\scipy\integrate\odepack.py:218: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

#
# 9.729730e+99    4.094426e-80  1.034790e+166  1.530929e+224   3.224197e+88
# 9.739740e+99   6.912859e-100  6.251193e+174  2.134044e+113  4.984351e+121
# 9.749750e+99    1.340686e-80  6.800304e+213  1.934389e+281   1.054514e-36
# 9.759760e+99   6.703797e+117   4.711876e-62   1.684166e-99  6.877954e+246
# 9.769770e+99   7.177347e+116  1.793820e+213  1.398155e+166   8.221643e+73
# 9.779780e+99    2.485554e+78   3.195760e-80  1.198255e+175   2.545744e-75
# 9.789790e+99   3.649616e+238   1.078714e+79   8.734142e-43   2.952413e+11
# 9.799800e+99    7.765292e-66   1.107344e+74   4.818664e+35  4.391544e+262
# 9.809810e+99    1.004645e+74  7.009144e+251  8.801234e+193   1.225687e-46
# 9.819820e+99   9.240968e+112   3.046053e+44   4.727291e-62  1.553410e+266
# 9.829830e+99   9.537011e+116  2.285473e+237  6.632143e+184   5.343041e+39
# 9.839840e+99   3.326110e+238   1.108448e-99   7.156233e+74  9.605717e+117
# 9.849850e+99    1.607090e-41   1.097228e+69   5.662381e+21   3.894183e-80
# 9.859860e+99    1.063074e+50  6.742286e+275  1.415708e+224   3.420790e-71
# 9.869870e+99   1.077382e+113   1.669700e+06  6.412909e+184   1.717075e-52
# 9.879880e+99    7.973011e+98   2.194941e-76   7.700637e-57  7.009144e+251
# 9.889890e+99    1.926021e+30   2.130279e+40  1.471721e+224  3.449690e+126
# 9.899900e+99   2.058509e+166   3.513492e-75  4.106907e+198  2.675310e+184
# 9.909910e+99   2.049607e+184   1.053260e-51   7.978772e+40  9.185843e+242
# 9.919920e+99   4.837345e+227  3.173018e+180  6.781603e+170   2.797813e-99
# 9.929930e+99   1.253835e+219   3.036261e+59  1.262761e+266  1.642641e+127
# 9.939940e+99   9.889506e+271  2.316780e+117  3.710488e+108   1.263162e+88
# 9.949950e+99   6.259793e+174  2.063733e+204   2.030550e-70  1.031334e+113
# 9.959960e+99    3.005802e+20  2.374455e+170   1.740247e-99  8.280831e+270
# 9.969970e+99   1.340817e+277   1.673056e+31  1.981439e+237   2.024333e+88
# 9.979980e+99    1.032523e+98  1.627088e+213   1.100820e+35   2.567849e-99
# 9.989990e+99   2.394980e+180   1.394526e-75   1.332223e+59  5.780009e+175
# 1.000000e+100  2.225782e+194   1.270843e-71  3.519220e+112   1.336920e+06
#
# [1000 rows x 4 columns]>

# %%
plot(system.results.x, system.results.y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A= Vector(2, -1) *m

B= Vector(0, 5)

A.proj(B)

C= 12*A.hat()


print(type(A), type(A.x))
C.x
# Out:
# <class 'modsim._Vector'> <class 'modsim._Vector'>
# <Quantity(10.73312629199899, 'dimensionless')>
